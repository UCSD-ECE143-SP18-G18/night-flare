# %%
# %matplotlib notebook
import sys
import os

sys.path.append(os.path.join(os.getcwd(), "packages"))
from IPython.display import HTML
from visualization import *

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Interactive GUI
#
# Plotting processed images with widgets.
# Widgets are controlled by the user and updates plot interactively
#
# About Plot:
# * (x_label, y_label): (latitude, longitude)
#     * San Diego's coordinates: (-117.1625, 32.7150)
#     * Los angeles's coordinates: (-118.2436, 34.0522)
# * Range of Longitude : (-180 ~ 180)
# * Range of Latitude : (-90 ~ 90)
# * Level of Pollution: Serious light pollution on brighter white color
#
# Explanations on widgets:
# * Buttons: Updating plot by the direction clicked
# * Possible button range : Same limit as Latitude and Longitude
#
#
# * Slider: Updating zoom in level of a plot
# * Possible Zoom in level : 1 ~ 7
#
# *Single image represents average of 30 days starting from given "date".

# %%
static_plot = StaticPlot(date = '2017-01-01')
static_plot.subplot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# VkJveChjaGlsZHJlbj0oSEJveChjaGlsZHJlbj0oQnV0dG9uKGRlc2NyaXB0aW9uPXUnTGVmdCcsIHN0eWxlPUJ1dHRvblN0eWxlKCkpLCBCdXR0b24oZGVzY3JpcHRpb249dSdSaWdodCcsIHPigKY=
# IntSlider(value=5, description=u'Zoom in', max=7, min=1)
# /Users/shijia/anaconda2/envs/ECE143/lib/python2.7/site-packages/scipy/signal/signaltools.py:940: RuntimeWarning: divide by zero encountered in true_divide
#   res *= (1 - noise / lVar)
# /Users/shijia/anaconda2/envs/ECE143/lib/python2.7/site-packages/scipy/signal/signaltools.py:940: RuntimeWarning: invalid value encountered in multiply
#   res *= (1 - noise / lVar)

# %% [markdown]
# ## Animation flow
# Using Animation, it shows flow of light pollution by the month range.
#
# Ipython HTML GUI allows us to control and select the frame interactively
#
# About plot:
# * Title: First day of 31 days
# * (x_label, y_label): (latitude, longitude)
#     * San Francisco's coordinates: (-122.4527, 37.7635)
# * Level of Pollution: Serious light pollution on brighter white color
#
# *Single frame represents the average of a month corresponding to the date above.

# %%
dynamic_plot = AnimatedPlot(start_date = '2017-01-01', end_date = '2018-01-01')
ani = dynamic_plot.subplot()
plt.close(ani._fig)
HTML(ani.to_jshtml())
# Out:
# <img src="data:image/png;base64,..." width="640">
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
# ...
