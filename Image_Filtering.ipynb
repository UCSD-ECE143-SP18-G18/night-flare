# %%
import sys
import os

sys.path.append(os.path.join(os.getcwd(), "packages"))
import getimage

# %%
from numpy import *
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
import imageio
l = getimage.get_image_date_range()
#imageio.imwrite("my.png", l[0])

plt.axis('off')

w,h=l[0].shape
arr=zeros((h,w),float)
N=len(l)

for im in l:
    imarr=array(im,dtype=float)
    arr=arr+imarr/N
out = matrix.round(arr)
out *= 255.0/out.max()    


plt.imshow(arr)
